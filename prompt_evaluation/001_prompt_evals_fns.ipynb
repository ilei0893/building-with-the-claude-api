# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.166666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\n\nlambda_config = {\n    \"FunctionName\": \"S3EventProcessor\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n    \"Handler\": \"index.handler\",\n    \"Timeout\": 60,\n    \"MemorySize\": 256,\n    \"Environment\": {\n        \"Variables\": {\n            \"DYNAMODB_TABLE_NAME\": \"s3-events-table\",\n            \"LOG_LEVEL\": \"INFO\"\n        }\n    },\n    \"Events\": {\n        \"S3Event\": {\n            \"Type\": \"S3\",\n            \"Properties\": {\n                \"Bucket\": \"source-bucket\",\n                \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"]\n            }\n        }\n    },\n    \"Architectures\": [\"x86_64\"],\n    \"EphemeralStorage\": {\n        \"Size\": 512\n    },\n    \"Tags\": {\n        \"Environment\": \"production\",\n        \"Application\": \"s3-event-processor\"\n    }\n}\n\nprint(json.dumps(lambda_config, indent=2))\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for a DynamoDB table name and log level",
#       "format": "json",
#       "solution_criteria": "Must include valid JSON structure with Lambda configuration properties, environment variables section containing DynamoDB table name and log level, and proper event source mapping for S3"
#     },
#     "score": 3.0,
#     "reasoning": "The solution successfully creates a valid JSON configuration with the core requirements: proper Lambda properties, environment variables for DynamoDB table and log level, and S3 event configuration. However, there is a significant architectural issue: the 'Events' section uses SAM template syntax rather than the AWS Lambda API format. Standard Lambda CreateFunction/UpdateFunctionConfiguration APIs do not accept event source mappings directly - these must be configured separately via S3 bucket notifications or EventSourceMapping resources. For a production-ready solution, the Events section should be removed or the configuration should be clarified as a SAM template. The hardcoded account ID and missing VPC/DLQ configs are secondary concerns but reduce production-readiness."
#   },
#   {
#     "output": "\nimport re\n\ndef extract_account_and_region_from_arn(arn: str) -> dict:\n    \"\"\"\n    Extracts AWS account ID and region from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \"\"\"\n    pattern = r'^arn:aws[a-z\\-]*:[^:]+:([^:]*):([^:]+):'\n    match = re.match(pattern, arn)\n    \n    if match:\n        return {\n            'region': match.group(1),\n            'account_id': match.group(2)\n        }\n    return {\n        'region': None,\n        'account_id': None\n    }\n",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID and region from an ARN string",
#       "format": "python",
#       "solution_criteria": "Function should parse ARN format (arn:aws:service:region:account-id:resource), correctly extract account ID and region, handle edge cases like resources without account IDs, and return results as a dictionary or tuple"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement for standard ARNs and uses appropriate regex matching. However, it doesn't fully address the criterion about handling 'resources without account IDs'\u2014many AWS resources (like S3 buckets, IAM roles) have ARNs where the account-id field is empty. The current pattern treats empty account IDs as None rather than empty strings, which may not be semantically correct. The solution also lacks input validation and format verification for extracted values. These issues would cause failures on real-world ARN variations."
#   },
#   {
#     "output": "\n^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regular expression pattern that validates AWS S3 bucket names according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens, must start and end with letter or number)",
#       "format": "regex",
#       "solution_criteria": "Regex pattern must enforce length constraints (3-63 chars), allow only lowercase letters, numbers and hyphens, require starting and ending with alphanumeric characters, and reject invalid bucket names like those with consecutive hyphens or uppercase letters"
#     },
#     "score": 7.5,
#     "reasoning": "The regex correctly validates most AWS S3 bucket naming rules including character set restrictions and alphanumeric boundaries. However, it has a critical flaw: the optional group `([a-z0-9-]{1,61}[a-z0-9])?` makes the middle and ending portions optional, allowing single character matches like 'a' which violates the 3-character minimum requirement. The pattern should be restructured to enforce exactly 3-63 characters without making portions optional. A corrected version would be: `^[a-z0-9]([a-z0-9-]{0,61}[a-z0-9]|[a-z0-9]{1,2})$` or similar logic."
#   }
# ]
